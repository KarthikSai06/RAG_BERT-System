# %% [markdown]
# # Domain-Specific RAG Helpdesk
#
# This notebook runs the full RAG pipeline (BERT Guardrail -> Sentence-BERT Retrieval -> 4-bit Mistral-7B) entirely within a Google Colab instance.

# %%
# !pip install -r requirements.txt

# %%
# !python src/ingest.py
# !python src/generate_synthetic_data.py
# !python src/train_classifier.py
# !python src/indexer.py

# %%
# To run the Streamlit UI via localtunnel
# !npm install localtunnel
import urllib
print("Password/Enpoint IP for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())
# !streamlit run app.py & npx localtunnel --port 8501
